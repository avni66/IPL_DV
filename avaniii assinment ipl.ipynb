# %% [markdown]
# #                       DV Assignment 1  IPL-Data-Analysis
#
# ###                                                      Name:Ananya pandey
# ###                                                      Batch:BCADS (12)
# ###                                                      University Roll_no : 1250258081

# %%
import numpy as np
import pandas as pd 
ipl_matchs=pd.read_csv("matches.csv")
ipl_matchs
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
ipl_matchs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
ipl_matchs.duplicated().sum()
# Out:
# np.int64(0)

# %%
max_win=ipl_matchs["win_by_runs"]
max_win.sort_values(ascending=False).head(5)
# Out:
# 43     146
# 619    144
# 59     140
# 556    138
# 410    130
# Name: win_by_runs, dtype: int64

# %% [markdown]
# ## i Match won by the maximum margin of runs

# %%
 
import matplotlib.pyplot as plt
import seaborn as sb
max_win=ipl_matchs.sort_values("win_by_runs",ascending=False).head(5)
y=max_win["win_by_runs"]
x=max_win["id"]
sb.barplot(x=x,y=y,color="yellow",edgecolor="black")
plt.title(" Match won by the maximum margin of runs",color="red")
plt.ylabel("RUNS",color="green")
plt.xlabel("Match_id",color="darkgreen")
plt.show()

# %% [markdown]
# Insights :
# Mumbai Indians recorded a huge 146-run victory against Delhi Daredevils, which is one of the biggest winning margins in the league’s history.
# This massive win shows Mumbai’s strong dominance during the 2017 season.
# Such a large margin usually means the team performed excellently in batting and then quickly dismissed the opposition with strong bowling.

# %%
ipl_matchs[ipl_matchs["id"]==44]
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2 umpire3
# 43  Nitin Menon  CK Nandan     NaN

# %%
max_win.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
ipl_matchs.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
ipl_matchs["city"] = ipl_matchs["city"].fillna("NA")

# %%
ipl_matchs.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
ipl_matchs["winner"].nunique()
# Out:
# 15

# %%
ipl_matchs["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
ipl_matchs["player_of_match"].fillna("No_Award",inplace=True)

# %%
ipl_matchs["winner"].fillna("No Result",inplace=True)

# %%
ipl_matchs["winner"].isnull().sum()
# Out:
# np.int64(0)

# %%
ipl_matchs["umpire1"].fillna("Unknown",inplace=True)
ipl_matchs["umpire2"].fillna("Unknown",inplace=True)
ipl_matchs["umpire3"].fillna("Unknown",inplace=True)

# %%
wicket_win=ipl_matchs.sort_values("win_by_wickets",ascending=False).head(12)
wicket_win
# Out:
#        id  season        city        date             team1  \
# 2       3    2017      Rajkot  2017-04-07     Gujarat Lions
# 298   299    2011      Mumbai  2011-05-20    Mumbai Indians
# 683  7941    2018      Indore    14/05/18   Kings XI Punjab
# 34     35    2017  Chandigarh  2017-04-30  Delhi Daredevils
# 590   591    2016      Rajkot  2016-04-21     Gujarat Lions
# 71     72    2008      Mumbai  2008-04-27    Mumbai Indians
# 542   543    2015       Delhi  2015-04-26  Delhi Daredevils
# 183   184    2010   Bangalore  2010-03-18  Rajasthan Royals
# 390   391    2013  Chandigarh  2013-04-10   Kings XI Punjab
# 376   377    2012      Jaipur  2012-05-20  Rajasthan Royals
# 119   120    2009   Cape Town  2009-04-19   Kings XI Punjab
# 677  7935    2018       Delhi    10/05/18  Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %% [markdown]
# ## ii> Match won by maximum wickets.

# %%
import matplotlib.pyplot as plt
import seaborn as sb
y=wicket_win["win_by_wickets"]
x=wicket_win["id"]
sb.barplot(x=x,y=y,palette="plasma",edgecolor="black",hue=y)
plt.title("Match_won_by_Max wicket",color="red")
plt.ylabel("win_by_wicket",color="blue")
plt.xlabel("Match_ID",color="blue")
plt.show()

# %% [markdown]
# Insights :
# There have been multiple matches with 10-wicket victories, including Kolkata Knight Riders against Gujarat Lions in 2017.
# A 10-wicket win means the chasing team reached the target without losing any wickets, showing a very strong opening partnership.
# These wins usually happen when the target is low and the bowling team fails to take early wickets.

# %% [markdown]
# ## iii> Match won by the minimum margin of runs.

# %%
min_run_win=ipl_matchs[ipl_matchs["win_by_runs"]!=0].sort_values("win_by_runs",ascending=True).head(15)
import matplotlib.pyplot as plt
import seaborn as sb
y=min_run_win["win_by_runs"]
x=min_run_win["id"]
sb.barplot(x=x,y=y,palette="cividis",edgecolor="red",hue=y)
plt.title("Min_runs_win",color="black")
plt.xticks(rotation=45)
plt.ylabel("win_by_runs",color="blue")
plt.xlabel("match_id",color="blue")
plt.show()

# %% [markdown]
# Insights :
# Some matches are won by just 1 run, such as Mumbai Indians vs. Chennai Super Kings in the 2019 final.
# Wins by a single run usually happen in high-pressure games like playoffs or finals.

# %%
ipl_matchs[ipl_matchs["win_by_runs"]==1]
# Out:
#         id  season          city        date                        team1  \
# 58      59    2017     Hyderabad  2017-05-21               Mumbai Indians
# 105    106    2008        Mumbai  2008-05-21              Kings XI Punjab
# 163    164    2009  Johannesburg  2009-05-17              Kings XI Punjab
# 344    345    2012         Delhi  2012-04-29             Delhi Daredevils
# 350    351    2012          Pune  2012-05-03               Mumbai Indians
# 518    519    2015       Chennai  2015-04-09          Chennai Super Kings
# 598    599    2016         Delhi  2016-04-27                Gujarat Lions
# 614    615    2016    Chandigarh  2016-05-09  Royal Challengers Bangalore
# 734  11330    2019     Bengaluru    21/04/19  Royal Challengers Bangalore
# 755  11415    2019     Hyderabad    12/05/19               Mumbai Indians
#
#                       team2          toss_winner toss_decision  result  \
# 58   Rising Pune Supergiant       Mumbai Indians           bat  normal
# ...

# %% [markdown]
# ## iv>. Match won by minimum wickets.

# %%
min_wicket_win=ipl_matchs[ipl_matchs["win_by_wickets"]!=0].sort_values("win_by_wickets",ascending=True).head(10)
import matplotlib.pyplot as plt
import seaborn as sb
y=min_wicket_win["win_by_wickets"]
x=min_wicket_win["id"]
sb.barplot(x=x,y=y,color="brown",edgecolor="black")
plt.ylabel("wickets",color="black")
plt.xlabel("match_id",color="black")
plt.title("Match won by minimum wickets",color="black")
plt.show()

# %% [markdown]
# Insights:
# A 1-wicket win means the match was extremely close, going down to the last pair of batsmen.
# These games highlight the importance of lower-order contributions in securing victories.

# %% [markdown]
# ## v>. Matches where D/L method was and wasn't applied.

# %%
dl_method=ipl_matchs["dl_applied"].value_counts()
import matplotlib.pyplot as plt 
import seaborn as sb
plt.pie(dl_method.values,labels=["DSL_Method_Not_Applied","DSL_Method_Applied"],autopct="%1.1f%%",shadow=True,wedgeprops={"edgecolor":"black"})
plt.title("Matches where D/L method was and wasn't applied",fontsize=16,color="red")
plt.show()

# %% [markdown]
# **Insights:
# 1. A very small percentage of matches used DL , which is only 2.5 %
# 2. Rain impact is limited but significant.
# 3. D/L matches may affect fairness perception.**

# %% [markdown]
# ## vi> No. of matches held in each city.

# %%
city_matchs=ipl_matchs["city"].value_counts().sort_values(ascending=False).head(15)
import matplotlib.pyplot as plt 
import seaborn as sb
sb.barplot(y=city_matchs.index,x=city_matchs.values,palette="turbo",edgecolor="red",hue=city_matchs)
plt.xlabel("No of Matches",fontsize=16,color="green")
plt.ylabel("City",fontsize=16,color="green")
plt.title("No of matches held in each city",fontsize=20,color="green")
plt.show()

# %% [markdown]
# **Insights :
# 1. Mumbai, Kolkata, Delhi usually host more matches.
# 2. Some cities host very few matches.
# 3. Helps BCCI understand stadium utilization.**

# %% [markdown]
# ## vii> No. of matches won by each team.

# %%
each_team_win=ipl_matchs["winner"].value_counts()
import matplotlib.pyplot as plt
import seaborn as sb
sb.barplot(y=each_team_win.index,x=each_team_win.values,edgecolor="black",hue=each_team_win)
plt.ylabel("Winning Team",fontsize=16,color='green')
plt.xlabel("No of Win",fontsize=16,color="green")
plt.ylabel("Winning team",fontsize=16,color="green")
plt.title("No of Matches Won by each team",fontsize=20,color="green")
plt.show()

# %% [markdown]
# **Insights:
# 1. Mumbai Indians lead the tally, reflecting their status as one of the most successful franchises
# 2. Chennai Super Kings and Kolkata Knight Riders follow.**

# %% [markdown]
# ## viii> No. of matches held every season.

# %%
no_of_matches_each_season=ipl_matchs["season"].value_counts()
import matplotlib.pyplot as plt 
import seaborn as sb
plt.Figure(figsize=(9,15))
sb.lineplot(y=no_of_matches_each_season.values,x=no_of_matches_each_season.index,marker="o",linestyle="--",color="black")
plt.xlim(2008,2019)
plt.xlabel("Season",fontsize=16,color="red")
plt.ylabel("No of Matches",fontsize=16,color="red")
plt.title("No of Matches held in every season", color="red",fontsize=20)
plt.ylim(55,80)
plt.grid()
plt.show()

# %% [markdown]
# Insights:
# 1. trend -Ranges from 57 to 76 matches per season
# 2. The seasons 2011–2013 saw the highest number of matches

# %% [markdown]
# ## ix> Top 10 players based on no. of Man of Match (MOM) awards won.

# %%
mam_of_match=ipl_matchs["player_of_match"].value_counts().sort_values(ascending=False).head(10)
import matplotlib.pyplot as plt
import seaborn as sb 
sb.barplot(y=mam_of_match.index,x=mam_of_match.values,edgecolor="black",hue=mam_of_match)
plt.xlabel("No of Matches win",fontsize=16,color="blue")
plt.ylabel("Top Player of The Match",fontsize=16,color="blue")
plt.title("Leading 10 Players in Man of the Match Awards",fontsize=20,color="blue")
plt.xlim(0,25)
plt.show()

# %% [markdown]
# **Insights:
# 1. Chris Gayle's lead showcases his "match-winner" status as an impact player.
# 2. The list is dominated by batsmen, suggesting that batting performances are often more valued for MOM awards than bowling.**

# %% [markdown]
# ## x> Does winning the toss mean winning the match?

# %%
toss_match_win=(ipl_matchs["toss_winner"] == ipl_matchs["winner"])
import matplotlib.pyplot as plt
import seaborn as sb
toss_match_win=toss_match_win.map({True:"Win",False:"Lose"})
sb.countplot(x=toss_match_win,hue=toss_match_win,edgecolor="black")
plt.xlabel("Result")
plt.title("Win Toss Win Match",color="black",fontsize=16,fontstyle="italic",fontweight="bold",loc="center",pad=20)
plt.show()

# %% [markdown]
# Insights:
# 1. Toss helps, but it does not guarantee a win.
# 2. Many teams lost even after winning the toss.
# 3. Performance matters more than luck.
# 4. Toss may give slight advantage.

# %% [markdown]
# ## xi> What was the decision taken by captains when they won the toss?

# %%
toss_winning_decision=ipl_matchs["toss_decision"].value_counts()
import matplotlib.pyplot as plt
import seaborn as sb
plt.pie(x=toss_winning_decision,labels=toss_winning_decision,autopct="%1.1f%%",wedgeprops={"edgecolor":"black"},shadow=True)
legends=["Field","Bat"]
plt.legend(legends)
plt.title("Bat vs Field Decision",fontsize=20,color="black",fontweight="bold",fontstyle="italic")
plt.show()

# %% [markdown]
# **Insights:
# 1. Most captains usually choose to field first.
# 2. In the IPL, teams often feel more comfortable while chasing a target.
# 3. One possible reason for this is the dew factor, which makes it harder for bowler     to grip the ball in the second innings.**

# %%
ipl_matchs["season"].value_counts().count()
# Out:
# np.int64(12)

# %%
ipl_matchs["dl_applied"].value_counts()
# Out:
# dl_applied
# 0    737
# 1     19
# Name: count, dtype: int64

# %% [markdown]
# ## xii> No. of matches where D/L method was applied every season.

# %%
dsl_matches=ipl_matchs[ipl_matchs["dl_applied"]==1]
dsl_seasons=dsl_matches.groupby("season").size().sort_values(ascending=False)
dsl_seasons
import matplotlib.pyplot as plt
import seaborn as sb
order=[2016,2009,2011,2018,2008,2015,2014,2017]
sb.barplot(y=dsl_seasons.values,x=dsl_seasons.index,color="red",edgecolor="black",order=order)
plt.ylabel("No Of DLS Applied",fontsize=16,color="black",fontstyle="italic")
plt.xlabel("Season",color="Black",fontsize=16,fontstyle="italic")
plt.title("DLS Applied Matches Per Season",fontsize=20,fontweight="bold",fontstyle="italic")
plt.ylim(0,5)
plt.show()

# %% [markdown]
# Insight:
# 1. 2016 and 2011 saw higher D/L incidents.
# 2. A few seasons had more rain interruptions.
# 3. Weather conditions vary each year.
# 4. It slightly affects overall season statistics.

# %% [markdown]
# ## xiii> Different results for matches.

# %%
result=ipl_matchs["result"].value_counts()
import matplotlib.pyplot as plt
import seaborn as sb
x=result.index
y=result.values
sb.barplot(x=x,y=y,palette=["red","orange","skyblue"],edgecolor="black",hue=result)
legend=['Normal',"Tie","No Result"]
plt.xlabel("Result",color="black",fontsize=16,fontstyle="italic")
plt.ylabel("Count Of Results",fontsize=16,color='black',fontstyle="italic")
plt.title("Match Outcomes",color="black",fontsize=20,fontstyle="italic",fontweight="bold")
plt.show()

# %% [markdown]
# **Insights:
# 1. Over 98% of matches end in a "Normal" result.
# 2. Very few matches were tied.
# 3. Some matches had no result due to rain.**

# %% [markdown]
# ## xiv> How many times did a team win the toss?

# %%
teams=ipl_matchs['toss_winner'].value_counts().sort_values(ascending=False )
import matplotlib.pyplot as plt
import seaborn as sb 
y=teams.index
x=teams.values
sb.barplot(y=y,x=x,edgecolor="black",palette="pastel",hue=teams)
plt.ylabel('Toss_Winner',fontsize=16,color="black",fontstyle="italic")
plt.xlabel("Count Of Toss_Win",fontsize=16,fontstyle="italic",color="black")
plt.title("Toss_Wins_By_Team",color="black",fontsize=20,fontstyle="italic",loc="left",pad=20)
plt.show()

# %% [markdown]
# **Insights:
# 1. Mumbai Indians are the leader mainly because they have played the most matches, which gave them more chances to win tosses.
# 2. Toss wins are mostly based on luck and are usually linked to how many matches a team has played.**

# %% [markdown]
# ## xv> Best venue for defending and chasing a total.

# %%
top_venue_chase=(ipl_matchs["win_by_runs"]>0).groupby(ipl_matchs["venue"]).sum().sort_values(ascending=False).head()
top_venue_chase
# Out:
# venue
# Wankhede Stadium                   35
# Feroz Shah Kotla                   33
# Eden Gardens                       32
# M Chinnaswamy Stadium              30
# MA Chidambaram Stadium, Chepauk    30
# Name: win_by_runs, dtype: int64

# %%
ipl_matchs[ipl_matchs["win_by_runs"]>0].head()
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
top_venue_chase=(ipl_matchs["win_by_runs"]>0).groupby(ipl_matchs["venue"]).sum().sort_values(ascending=False).head()
import matplotlib.pyplot as plt
import seaborn as sb
x=top_venue_chase.index
y=top_venue_chase.values
sb.barplot(x=y,y=x,palette="viridis",edgecolor="black",linewidth=2,hue=top_venue_chase)
plt.ylabel("Venue",fontsize=16,color="black",fontstyle="italic")
plt.xlabel("No Of Matches Win",color="black",fontsize=16,fontstyle="italic")
plt.title("Venue VS Defending win",color="black",fontsize=20,fontstyle="italic",loc="left",pad=20,fontweight="bold")
plt.show()

# %%
ipl_matchs[ipl_matchs["win_by_wickets"]>0].head()
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %%
top_venue_defend=(ipl_matchs["win_by_wickets"]>0).groupby(ipl_matchs["venue"]).sum().sort_values(ascending=False).head()
import matplotlib.pyplot as plt
import seaborn as sb
x=top_venue_defend.values
y=top_venue_defend.index
sb.barplot(x=x,y=y,palette="viridis",hue=top_venue_defend,edgecolor="black",linewidth=2)
plt.ylabel("Venue",color="black",fontsize=16,fontstyle="italic")
plt.xlabel("No Of Matches Win",color="black",fontsize=16,fontstyle="italic")
plt.title("Venue VS Chasing Win",color="black",fontweight="bold",fontsize=20,fontstyle="italic",loc="left")
plt.show()

# %% [markdown]
# Insights:
# 1. Wankhede Stadium and Feroz Shah Kotla are the best venues for chasing runs, as teams often win while batting second there.
# 2. Eden Gardens and M. Chinnaswamy Stadium are better for defending totals, where teams batting first have a higher chance of winning.

# %% [markdown]
# ## xvi> Best defending and chasing teams.

# %%
ipl_matchs[ipl_matchs["win_by_wickets"]!=0].head()
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %%
best_defending_teams=(ipl_matchs["win_by_wickets"]!=0).groupby(ipl_matchs["winner"]).sum().sort_values(ascending=False).head(10)
import matplotlib.pyplot as plt 
import seaborn as sb
x=best_defending_teams.index
y=best_defending_teams.values
sb.barplot(x=y,y=x,hue=best_defending_teams,palette="pastel",edgecolor="black")
plt.ylabel("Winner_Teams",color="red",fontsize=16,fontstyle='italic')
plt.xlabel("No Of Win",color="red",fontsize=16,fontstyle="italic")
plt.title("Win By Chasing  Vs Teams",color="black",fontsize=20,fontstyle="italic",fontweight="bold",loc="left",pad=20)
plt.show()

# %%
ipl_matchs[ipl_matchs['win_by_runs']!=0].head()
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
best_chasing_teams=(ipl_matchs["win_by_runs"]!=0).groupby(ipl_matchs["winner"]).sum().sort_values(ascending=False).head(10)
import matplotlib.pyplot as plt
import seaborn as sb
x=best_chasing_teams.values
y=best_chasing_teams.index
sb.barplot(x=x,y=y,hue=best_chasing_teams,palette="pastel",edgecolor="black")
plt.ylabel("Winning Teams",color="red",fontsize=16,fontstyle="italic")
plt.xlabel("No Of Win",color="red",fontsize=16,fontstyle="italic")
plt.title("Win_By_Defending VS Teams",color="black",fontsize=20,fontstyle="italic",fontweight="bold",loc="left",pad=20)
plt.show()

# %% [markdown]
# Insights:
# 1. Kolkata Knight Riders and Mumbai Indians have been strong teams while chasing targets.
# 2. Chennai Super Kings and Mumbai Indians have also performed well in defending totals.

# %% [markdown]
# ## xvii> No. of matches played in different stadiums.

# %%
top_played_venue=ipl_matchs["venue"].value_counts().sort_values(ascending=False).head(15)
top_played_venue
# Out:
# venue
# Eden Gardens                                            77
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Name: count, dtype: int64

# %%
top_played_venue=ipl_matchs["venue"].value_counts().sort_values(ascending=False).head(15)
import matplotlib.pyplot as plt 
import seaborn as sb
x=top_played_venue.values
y=top_played_venue.index
sb.barplot(x=x,y=y,hue=top_played_venue,edgecolor="black",palette="viridis")
plt.ylabel("Stadiums",color="gray",fontsize=16,fontstyle="italic")
plt.xlabel("No Of Matches Played",color="gray",fontsize=16,fontstyle="italic")
plt.title("No_Of Matches_Played_In Different_Stadiums",color="black",fontsize=20,fontstyle="italic",fontweight="bold",loc="right",pad=20)
plt.show()

# %% [markdown]
# Insights:
# 1. Eden Gardens is the top stadium with 75 matches and is often chosen for major games because of its large seating capacity.
# 2. Wankhede Stadium and M. Chinnaswamy Stadium are also important and frequently used venues.

# %%
ipl_matchs.to_excel("ipl_matchs.xlsx")
